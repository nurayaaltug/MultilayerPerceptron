# %% [markdown]
# <a href="https://colab.research.google.com/github/nurayaaltug/MultilayerPerceptron/blob/main/MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


class MLP(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, output_size)
        self.activation = nn.ReLU()

    def forward(self, x):
        x = self.activation(self.fc1(x))
        x = self.activation(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))  
        return x
input_size = 13
hidden_size1 = 100
hidden_size2 = 50
output_size = 2
learning_rate = 0.01
num_epochs = 50
batch_size = 16

model = MLP(input_size, hidden_size1, hidden_size2, output_size)

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# %%
class PrincessDataset(Dataset):
    def __init__(self, data):
        self.data = data
        self.X = data.iloc[:, :-1].values
        self.y = data.iloc[:, -1].values

        scaler = StandardScaler()
        self.X = scaler.fit_transform(self.X)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = torch.FloatTensor(self.X[idx])
        y = torch.LongTensor([self.y[idx]])
        return X, y


train_data = pd.read_csv('sample_data/cure_the_princess_train.csv')
valid_data = pd.read_csv('sample_data/cure_the_princess_validation.csv')
test_data = pd.read_csv('sample_data/cure_the_princess_test.csv')


train_dataset = PrincessDataset(train_data)
valid_dataset = PrincessDataset(valid_data)
test_dataset = PrincessDataset(test_data)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)

torch.manual_seed(190401056)
best_accuracy = 0
best_epoch = 0
patience = 5
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target.squeeze())
        loss.backward()
        optimizer.step()


    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in valid_loader:
            output = model(data)
            val_loss = criterion(output, target.squeeze())
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target.squeeze()).sum().item()
    
    accuracy = 100 * correct / total
    print('Epoch: {}, Validation Accuracy: {:.2f}%'.format(epoch+1, accuracy))
    print('Epoch: {}, Batch: {}, training Loss: {:.4f}'.format(epoch+1, batch_idx+1, loss.item()))
    print('Epoch: {}, Batch: {}, val loss: {:.4f}'.format(epoch+1, batch_idx+1, val_loss.item()))
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_epoch = epoch
        torch.save(model.state_dict(), 'best_model.pt')
  
    elif epoch - best_epoch > patience:
        print(f'Early stopping: validation accuracy has not improved for {patience} epochs.')
        break
train_losses = []
val_losses = []
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target.squeeze())
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_losses.append(train_loss/len(train_loader))

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in valid_loader:
            output = model(data)
            loss = criterion(output, target.squeeze())
            val_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target.squeeze()).sum().item()
        val_losses.append(val_loss/len(valid_loader))   

import matplotlib.pyplot as plt

plt.plot(train_losses, label='Training loss')
plt.plot(val_losses, label='Validation loss')
plt.legend()
plt.show()
# Out:
# Epoch: 1, Validation Accuracy: 51.59%
# Epoch: 1, Batch: 79, training Loss: 0.6921
# Epoch: 1, Batch: 79, val loss: 0.6920
# Epoch: 2, Validation Accuracy: 53.18%
# Epoch: 2, Batch: 79, training Loss: 0.6914
# Epoch: 2, Batch: 79, val loss: 0.6887
# Epoch: 3, Validation Accuracy: 55.41%
# Epoch: 3, Batch: 79, training Loss: 0.6835
# Epoch: 3, Batch: 79, val loss: 0.6884
# Epoch: 4, Validation Accuracy: 57.01%
# Epoch: 4, Batch: 79, training Loss: 0.6760
# Epoch: 4, Batch: 79, val loss: 0.6878
# Epoch: 5, Validation Accuracy: 59.55%
# Epoch: 5, Batch: 79, training Loss: 0.6826
# Epoch: 5, Batch: 79, val loss: 0.6919
# Epoch: 6, Validation Accuracy: 61.15%
# Epoch: 6, Batch: 79, training Loss: 0.6746
# Epoch: 6, Batch: 79, val loss: 0.6815
# Epoch: 7, Validation Accuracy: 63.38%
# Epoch: 7, Batch: 79, training Loss: 0.6813
# Epoch: 7, Batch: 79, val loss: 0.6897
# Epoch: 8, Validation Accuracy: 66.24%
# Epoch: 8, Batch: 79, training Loss: 0.6861
# Epoch: 8, Batch: 79, val loss: 0.6895
# Epoch: 9, Validation Accuracy: 70.06%
# Epoch: 9, Batch: 79, training Loss: 0.7043
# Epoch: 9, Batch: 79, val loss: 0.6771
# Epoch: 10, Validation Accuracy: 71.66%
# Epoch: 10, Batch: 79, training Loss: 0.6880
# Epoch: 10, Batch: 79, val loss: 0.6825
# Epoch: 11, Validation Accuracy: 74.20%
# Epoch: 11, Batch: 79, training Loss: 0.6712
# Epoch: 11, Batch: 79, val loss: 0.6680
# Epoch: 12, Validation Accuracy: 75.80%
# Epoch: 12, Batch: 79, training Loss: 0.6800
# Epoch: 12, Batch: 79, val loss: 0.6663
# Epoch: 13, Validation Accuracy: 76.75%
# Epoch: 13, Batch: 79, training Loss: 0.6593
# Epoch: 13, Batch: 79, val loss: 0.6597
# Epoch: 14, Validation Accuracy: 78.66%
# Epoch: 14, Batch: 79, training Loss: 0.6677
# Epoch: 14, Batch: 79, val loss: 0.6363
# Epoch: 15, Validation Accuracy: 80.25%
# Epoch: 15, Batch: 79, training Loss: 0.6467
# Epoch: 15, Batch: 79, val loss: 0.6496
# Epoch: 16, Validation Accuracy: 80.89%
# Epoch: 16, Batch: 79, training Loss: 0.6645
# Epoch: 16, Batch: 79, val loss: 0.6784
# Epoch: 17, Validation Accuracy: 81.53%
# Epoch: 17, Batch: 79, training Loss: 0.6504
# Epoch: 17, Batch: 79, val loss: 0.6596
# Epoch: 18, Validation Accuracy: 82.80%
# Epoch: 18, Batch: 79, training Loss: 0.6119
# Epoch: 18, Batch: 79, val loss: 0.6520
# Epoch: 19, Validation Accuracy: 82.17%
# Epoch: 19, Batch: 79, training Loss: 0.6421
# Epoch: 19, Batch: 79, val loss: 0.6355
# Epoch: 20, Validation Accuracy: 82.17%
# Epoch: 20, Batch: 79, training Loss: 0.6473
# Epoch: 20, Batch: 79, val loss: 0.6437
# Epoch: 21, Validation Accuracy: 82.80%
# Epoch: 21, Batch: 79, training Loss: 0.6655
# Epoch: 21, Batch: 79, val loss: 0.6379
# Epoch: 22, Validation Accuracy: 82.48%
# Epoch: 22, Batch: 79, training Loss: 0.6215
# Epoch: 22, Batch: 79, val loss: 0.6055
# Epoch: 23, Validation Accuracy: 83.44%
# Epoch: 23, Batch: 79, training Loss: 0.5899
# Epoch: 23, Batch: 79, val loss: 0.6694
# Epoch: 24, Validation Accuracy: 84.39%
# Epoch: 24, Batch: 79, training Loss: 0.6314
# Epoch: 24, Batch: 79, val loss: 0.6022
# Epoch: 25, Validation Accuracy: 84.08%
# Epoch: 25, Batch: 79, training Loss: 0.5492
# Epoch: 25, Batch: 79, val loss: 0.5732
# Epoch: 26, Validation Accuracy: 83.76%
# Epoch: 26, Batch: 79, training Loss: 0.5072
# Epoch: 26, Batch: 79, val loss: 0.5461
# Epoch: 27, Validation Accuracy: 83.76%
# Epoch: 27, Batch: 79, training Loss: 0.6375
# Epoch: 27, Batch: 79, val loss: 0.5307
# Epoch: 28, Validation Accuracy: 84.08%
# Epoch: 28, Batch: 79, training Loss: 0.5374
# Epoch: 28, Batch: 79, val loss: 0.5090
# Epoch: 29, Validation Accuracy: 85.67%
# Epoch: 29, Batch: 79, training Loss: 0.6663
# Epoch: 29, Batch: 79, val loss: 0.5613
# Epoch: 30, Validation Accuracy: 85.67%
# Epoch: 30, Batch: 79, training Loss: 0.4755
# Epoch: 30, Batch: 79, val loss: 0.5058
# Epoch: 31, Validation Accuracy: 85.35%
# Epoch: 31, Batch: 79, training Loss: 0.5446
# Epoch: 31, Batch: 79, val loss: 0.5630
# Epoch: 32, Validation Accuracy: 85.67%
# Epoch: 32, Batch: 79, training Loss: 0.6334
# Epoch: 32, Batch: 79, val loss: 0.5859
# Epoch: 33, Validation Accuracy: 85.99%
# Epoch: 33, Batch: 79, training Loss: 0.5019
# Epoch: 33, Batch: 79, val loss: 0.5318
# Epoch: 34, Validation Accuracy: 86.31%
# Epoch: 34, Batch: 79, training Loss: 0.7060
# Epoch: 34, Batch: 79, val loss: 0.5336
# Epoch: 35, Validation Accuracy: 86.31%
# Epoch: 35, Batch: 79, training Loss: 0.4296
# Epoch: 35, Batch: 79, val loss: 0.5893
# Epoch: 36, Validation Accuracy: 86.31%
# Epoch: 36, Batch: 79, training Loss: 0.4993
# Epoch: 36, Batch: 79, val loss: 0.4910
# Epoch: 37, Validation Accuracy: 86.31%
# Epoch: 37, Batch: 79, training Loss: 0.4987
# Epoch: 37, Batch: 79, val loss: 0.4943
# Epoch: 38, Validation Accuracy: 86.62%
# Epoch: 38, Batch: 79, training Loss: 0.5417
# Epoch: 38, Batch: 79, val loss: 0.4167
# Epoch: 39, Validation Accuracy: 87.90%
# Epoch: 39, Batch: 79, training Loss: 0.5265
# Epoch: 39, Batch: 79, val loss: 0.4134
# Epoch: 40, Validation Accuracy: 87.90%
# Epoch: 40, Batch: 79, training Loss: 0.5684
# Epoch: 40, Batch: 79, val loss: 0.4024
# Epoch: 41, Validation Accuracy: 88.54%
# Epoch: 41, Batch: 79, training Loss: 0.4624
# Epoch: 41, Batch: 79, val loss: 0.4549
# Epoch: 42, Validation Accuracy: 88.54%
# Epoch: 42, Batch: 79, training Loss: 0.4589
# Epoch: 42, Batch: 79, val loss: 0.4359
# Epoch: 43, Validation Accuracy: 88.54%
# Epoch: 43, Batch: 79, training Loss: 0.6114
# Epoch: 43, Batch: 79, val loss: 0.4375
# Epoch: 44, Validation Accuracy: 88.85%
# Epoch: 44, Batch: 79, training Loss: 0.3589
# Epoch: 44, Batch: 79, val loss: 0.4167
# Epoch: 45, Validation Accuracy: 89.17%
# Epoch: 45, Batch: 79, training Loss: 0.5090
# Epoch: 45, Batch: 79, val loss: 0.4263
# Epoch: 46, Validation Accuracy: 89.17%
# Epoch: 46, Batch: 79, training Loss: 0.3436
# Epoch: 46, Batch: 79, val loss: 0.4211
# Epoch: 47, Validation Accuracy: 89.49%
# Epoch: 47, Batch: 79, training Loss: 0.4144
# Epoch: 47, Batch: 79, val loss: 0.3939
# Epoch: 48, Validation Accuracy: 89.17%
# Epoch: 48, Batch: 79, training Loss: 0.4642
# Epoch: 48, Batch: 79, val loss: 0.4923
# Epoch: 49, Validation Accuracy: 89.17%
# Epoch: 49, Batch: 79, training Loss: 0.4387
# Epoch: 49, Batch: 79, val loss: 0.4068
# Epoch: 50, Validation Accuracy: 89.49%
# Epoch: 50, Batch: 79, training Loss: 0.4289
# Epoch: 50, Batch: 79, val loss: 0.4385

# %%
train_losses = []
val_losses = []
torch.manual_seed(190401056)

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target.squeeze())
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_losses.append(train_loss/len(train_loader))

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in valid_loader:
            output = model(data)
            loss = criterion(output, target.squeeze())
            val_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target.squeeze()).sum().item()
        val_losses.append(val_loss/len(valid_loader))
    
    accuracy = 100 * correct / total
    print('Epoch: {}, Validation Accuracy: {:.2f}%'.format(epoch+1, accuracy))
 
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_epoch = epoch
        torch.save(model.state_dict(), 'best_model.pt')
 
    elif epoch - best_epoch > patience:
        print(f'Early stopping: validation accuracy has not improved for {patience} epochs.')
        break

import matplotlib.pyplot as plt

plt.plot(train_losses, label='Training loss')
plt.plot(val_losses, label='Validation loss')
plt.legend()
plt.show()
# Out:
# Epoch: 1, Validation Accuracy: 95.22%
# Epoch: 2, Validation Accuracy: 95.22%
# Epoch: 3, Validation Accuracy: 95.22%
# Epoch: 4, Validation Accuracy: 95.22%
# Epoch: 5, Validation Accuracy: 95.22%
# Epoch: 6, Validation Accuracy: 95.22%
# Epoch: 7, Validation Accuracy: 95.22%
# Early stopping: validation accuracy has not improved for 5 epochs.

# %%
best_model = MLP(input_size, hidden_size1, hidden_size2, output_size)

best_model.load_state_dict(torch.load("best_model.pt"))

best_model.eval()
# Out:
# MLP(
#   (fc1): Linear(in_features=13, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=2, bias=True)
#   (activation): ReLU()
# )

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

best_model.eval()

test_loader = DataLoader(test_dataset, batch_size=len(test_dataset), shuffle=False)
X_test, y_test = next(iter(test_loader))

with torch.no_grad():
    output = best_model(X_test)
    _, predicted = torch.max(output.data, 1)

accuracy = accuracy_score(y_test.squeeze().numpy(), predicted.numpy()) * 100
report = classification_report(y_test.squeeze().numpy(), predicted.numpy(), target_names=["Not Saved", "Saved"])

print(f"Accuracy: {accuracy:.2f}%")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 93.91%
# Classification Report:
#               precision    recall  f1-score   support
#
#    Not Saved       0.93      0.95      0.94       384
#        Saved       0.95      0.93      0.94       388
#
#     accuracy                           0.94       772
#    macro avg       0.94      0.94      0.94       772
# weighted avg       0.94      0.94      0.94       772
